# %% [markdown]
# <a href="https://colab.research.google.com/github/akiitr/python/blob/master/Notebooks/colab_ebook2audiobook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Welcome to the ebook2audiobook free google colab!
# ## 🌟 Features
#
# - 📖 Converts eBooks to text format with Calibre.
# - 📚 Splits eBook into chapters for organized audio.
# - 🎙️ High-quality text-to-speech with Coqui XTTS and Fairseq.
# - 🗣️ Optional voice cloning with your own voice file or choose from our pre-made fine-tuned models!
# - 🌍 Supports multiple languages! Arabic (ar), Chinese (zh-cn), Czech (cs), Dutch (nl), English (en), French (fr), German (de), Hindi (hi), Hungarian (hu), Italian (it), Japanese (ja), Korean (ko), Polish (pl), Portuguese (pt), Russian (ru), Spanish (es), Turkish (tr), Vietnamese (vi), [+ 1107 languages via Fairseq](https://dl.fbaipublicfiles.com/mms/tts/all-tts-languages.html)
# ## Want to run locally for free? ⬇
# ## [Check out the ebook2audiobook github!](https://github.com/DrewThomasson/ebook2audiobook)

# %%
# @title 🛠️ Install requirments
#!DEBIAN_FRONTEND=noninteractive
# !sudo apt-get update # && sudo apt-get -y upgrade
# !sudo apt-get -y install libegl1
# !sudo apt-get -y install libopengl0
# !sudo apt-get -y install libxcb-cursor0
# !sudo -v && wget -nv -O- https://download.calibre-ebook.com/linux-installer.sh | sudo sh /dev/stdin
# !sudo apt-get install -y ffmpeg
# !apt-get install -y mecab libmecab-dev mecab-ipadic-utf8
# !pip install mecab-python3
#!sudo apt-get install -y calibre
#!git clone https://github.com/DrewThomasson/ebook2audiobook.git
# !git clone https://github.com/DrewThomasson/ebook2audiobook.git temp_repo && mv temp_repo/* temp_repo/.* ./ && rm -rf temp_repo
# !pip install -r /content/requirements.txt
# Out:
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:5 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:7 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:9 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libegl1 is already the newest version (1.4.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libopengl0 is already the newest version (1.4.0-1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libxcb-cursor0 is already the newest version (0.1.1-4ubuntu1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# 2025-01-08 18:16:11 URL:https://download.calibre-ebook.com/linux-installer.sh [35050/35050] -> "-" [1]
# Using python executable: /usr/bin/python3
# Installing to /opt/calibre
# Downloading tarball signature securely...
# Using previously downloaded calibre-7.23.0-x86_64.txz
# Extracting files to /opt/calibre ...
# Extracting application files...
# Creating symlinks...
# 	Symlinking /opt/calibre/ebook-device to /usr/bin/ebook-device
# 	Symlinking /opt/calibre/ebook-meta to /usr/bin/ebook-meta
# 	Symlinking /opt/calibre/ebook-convert to /usr/bin/ebook-convert
# 	Symlinking /opt/calibre/ebook-polish to /usr/bin/ebook-polish
# 	Symlinking /opt/calibre/markdown-calibre to /usr/bin/markdown-calibre
# 	Symlinking /opt/calibre/web2disk to /usr/bin/web2disk
# 	Symlinking /opt/calibre/calibre-server to /usr/bin/calibre-server
# 	Symlinking /opt/calibre/lrf2lrs to /usr/bin/lrf2lrs
# 	Symlinking /opt/calibre/lrs2lrf to /usr/bin/lrs2lrf
# 	Symlinking /opt/calibre/calibre-debug to /usr/bin/calibre-debug
# 	Symlinking /opt/calibre/calibredb to /usr/bin/calibredb
# 	Symlinking /opt/calibre/calibre-parallel to /usr/bin/calibre-parallel
# 	Symlinking /opt/calibre/calibre-customize to /usr/bin/calibre-customize
# 	Symlinking /opt/calibre/fetch-ebook-metadata to /usr/bin/fetch-ebook-metadata
# 	Symlinking /opt/calibre/calibre-smtp to /usr/bin/calibre-smtp
# 	Symlinking /opt/calibre/calibre to /usr/bin/calibre
# 	Symlinking /opt/calibre/lrfviewer to /usr/bin/lrfviewer
# 	Symlinking /opt/calibre/ebook-viewer to /usr/bin/ebook-viewer
# 	Symlinking /opt/calibre/ebook-edit to /usr/bin/ebook-edit
# Setting up command-line completion...
# Installing zsh completion to: /usr/share/zsh/vendor-completions/_calibre
# Failed to find directory to install bash completions, using default.
# Installing bash completion to: /usr/share/bash-completion/completions/
# Failed to import PyQt module: PyQt6.QtWebEngineCore with error: libXtst.so.6: cannot open shared object file: No such file or directory
#
# ____________________ WARNING ____________________
# Setting up completion failed with error:
# __________________________________________________
#
#
# 	Traceback (most recent call last):
# 	  File "calibre/linux.py", line 838, in setup_completion
# 	  File "calibre/linux.py", line 588, in write_completion
# 	  File "bypy-importer.py", line 279, in exec_module
# 	  File "calibre/gui2/tweak_book/main.py", line 12, in <module>
# 	  File "bypy-importer.py", line 279, in exec_module
# 	  File "calibre/ebooks/oeb/polish/check/css.py", line 12, in <module>
# 	ImportError: cannot import name 'QWebEnginePage' from 'qt.webengine' (/opt/calibre/lib/calibre-extensions/python-lib.bypy.frozen/qt/webengine.pyc)
#
# Setting up desktop integration...
# xdg-desktop-menu: No writable system menu directory found.
#
# ____________________ WARNING ____________________
# Setting up desktop integration failed with error:
# __________________________________________________
#
#
# 	Traceback (most recent call last):
# 	  File "calibre/linux.py", line 859, in setup_desktop_integration
# 	  File "calibre/linux.py", line 881, in do_setup_desktop_integration
# 	  File "calibre/linux.py", line 961, in install_xdg_junk
# 	  File "subprocess.py", line 413, in check_call
# 	subprocess.CalledProcessError: Command 'xdg-desktop-menu install --noupdate ./calibre-gui.desktop' returned non-zero exit status 3.
#
# Creating un-installer: /usr/bin/calibre-uninstall
#
#
# There were 2 warnings
#
# * Setting up completion failed with error:
#
# * Setting up desktop integration failed with error:
#
# Run "calibre" to start calibre
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libmecab-dev is already the newest version (0.996-14build9).
# mecab-ipadic-utf8 is already the newest version (2.7.0-20070801+main-3).
# mecab is already the newest version (0.996-14build9).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# Requirement already satisfied: mecab-python3 in /usr/local/lib/python3.10/dist-packages (1.0.10)
# Cloning into 'temp_repo'...
# remote: Enumerating objects: 2803, done.
# remote: Counting objects: 100% (698/698), done.
# remote: Compressing objects: 100% (308/308), done.
# remote: Total 2803 (delta 537), reused 392 (delta 389), pack-reused 2105 (from 6)
# Receiving objects: 100% (2803/2803), 203.07 MiB | 33.93 MiB/s, done.
# Resolving deltas: 100% (1438/1438), done.
# Updating files: 100% (9425/9425), done.
# mv: cannot move 'temp_repo/assets' to './assets': Directory not empty
# mv: cannot move 'temp_repo/audiobooks' to './audiobooks': Directory not empty
# mv: cannot move 'temp_repo/dockerfiles' to './dockerfiles': Directory not empty
# mv: cannot move 'temp_repo/ebook2audiobookXTTS.egg-info' to './ebook2audiobookXTTS.egg-info': Directory not empty
# mv: cannot move 'temp_repo/ebooks' to './ebooks': Directory not empty
# mv: cannot move 'temp_repo/lib' to './lib': Directory not empty
# mv: cannot move 'temp_repo/models' to './models': Directory not empty
# mv: cannot move 'temp_repo/Notebooks' to './Notebooks': Directory not empty
# mv: cannot move 'temp_repo/readme' to './readme': Directory not empty
# mv: cannot move 'temp_repo/tmp' to './tmp': Directory not empty
# mv: cannot move 'temp_repo/tools' to './tools': Directory not empty
# mv: cannot move 'temp_repo/voices' to './voices': Directory not empty
# mv: cannot move 'temp_repo/.' to './.': Device or resource busy
# mv: cannot move 'temp_repo/..' to './..': Device or resource busy
# mv: cannot move 'temp_repo/.git' to './.git': Directory not empty
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 1)) (4.12.3)
# Requirement already satisfied: coqui-tts in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 2)) (0.25.1)
# Requirement already satisfied: cutlet in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 3)) (0.5.0)
# Requirement already satisfied: deep_translator in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 4)) (1.11.4)
# Requirement already satisfied: docker in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 5)) (7.1.0)
# Requirement already satisfied: ebooklib in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 6)) (0.18)
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 7)) (4.3.3)
# Requirement already satisfied: gradio>=4.44 in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 8)) (5.10.0)
# Requirement already satisfied: hangul-romanize in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 9)) (0.1.0)
# Requirement already satisfied: indic-nlp-library in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 10)) (0.92)
# Requirement already satisfied: iso-639 in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 11)) (0.4.5)
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 12)) (0.42.1)
# Requirement already satisfied: m4b-util in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 13)) (2025.1.6)
# Requirement already satisfied: mecab in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 14)) (0.996.5)
# Requirement already satisfied: mecab-python3 in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 15)) (1.0.10)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 16)) (0.25.1)
# Requirement already satisfied: pypinyin in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 17)) (0.53.0)
# Requirement already satisfied: ray in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 18)) (2.40.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 19)) (4.46.2)
# Requirement already satisfied: translate in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 20)) (3.6.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 21)) (4.67.1)
# Requirement already satisfied: unidic in /usr/local/lib/python3.10/dist-packages (from -r /content/requirements.txt (line 22)) (1.1.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->-r /content/requirements.txt (line 1)) (2.6)
# Requirement already satisfied: anyascii>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (0.3.2)
# Requirement already satisfied: coqpit-config<0.2.0,>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (0.1.2)
# Requirement already satisfied: coqui-tts-trainer<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (0.2.2)
# Requirement already satisfied: cython>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (3.0.11)
# Requirement already satisfied: einops>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (0.8.0)
# Requirement already satisfied: encodec>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (0.1.1)
# Requirement already satisfied: fsspec>=2023.6.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2023.6.0->coqui-tts->-r /content/requirements.txt (line 2)) (2024.10.0)
# Requirement already satisfied: gruut>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from gruut[de,es,fr]>=2.4.0->coqui-tts->-r /content/requirements.txt (line 2)) (2.4.0)
# Requirement already satisfied: inflect>=5.6.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (7.5.0)
# Requirement already satisfied: librosa>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (0.10.2.post1)
# Requirement already satisfied: matplotlib>=3.7.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (3.10.0)
# Requirement already satisfied: monotonic-alignment-search>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (0.1.1)
# Requirement already satisfied: num2words>=0.5.11 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (0.5.14)
# Requirement already satisfied: numpy<2.0,>=1.25.2 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: packaging>=23.1 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (24.2)
# Requirement already satisfied: pysbd>=0.3.4 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (0.3.4)
# Requirement already satisfied: pyyaml>=6.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (6.0.2)
# Requirement already satisfied: scipy>=1.11.2 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: soundfile>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (0.13.0)
# Requirement already satisfied: spacy<3.8,>=3 in /usr/local/lib/python3.10/dist-packages (from spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (3.7.5)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (2.5.1+cu121)
# Requirement already satisfied: torchaudio>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts->-r /content/requirements.txt (line 2)) (2.5.1+cu121)
# Requirement already satisfied: jaconv in /usr/local/lib/python3.10/dist-packages (from cutlet->-r /content/requirements.txt (line 3)) (0.4.0)
# Requirement already satisfied: fugashi in /usr/local/lib/python3.10/dist-packages (from cutlet->-r /content/requirements.txt (line 3)) (1.4.0)
# Requirement already satisfied: mojimoji in /usr/local/lib/python3.10/dist-packages (from cutlet->-r /content/requirements.txt (line 3)) (0.0.13)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from deep_translator->-r /content/requirements.txt (line 4)) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from docker->-r /content/requirements.txt (line 5)) (2.3.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from ebooklib->-r /content/requirements.txt (line 6)) (5.3.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from ebooklib->-r /content/requirements.txt (line 6)) (1.17.0)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim->-r /content/requirements.txt (line 7)) (7.1.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (23.2.1)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (3.7.1)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (0.115.6)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (0.5.0)
# Requirement already satisfied: gradio-client==1.5.3 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (1.5.3)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.25.1 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (0.27.1)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (3.1.5)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (2.1.5)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (3.10.13)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (2.2.2)
# Requirement already satisfied: pillow<12.0,>=8.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (11.1.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (2.10.4)
# Requirement already satisfied: python-multipart>=0.0.18 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (0.0.20)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (0.8.6)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.6 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (0.1.6)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (2.10.0)
# Requirement already satisfied: starlette<1.0,>=0.40.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (0.41.3)
# Requirement already satisfied: tomlkit<0.14.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (0.13.2)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (0.15.1)
# Requirement already satisfied: typing-extensions~=4.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (4.12.2)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from gradio>=4.44->-r /content/requirements.txt (line 8)) (0.34.0)
# Requirement already satisfied: websockets<15.0,>=10.0 in /usr/local/lib/python3.10/dist-packages (from gradio-client==1.5.3->gradio>=4.44->-r /content/requirements.txt (line 8)) (14.1)
# Requirement already satisfied: sphinx-argparse in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library->-r /content/requirements.txt (line 10)) (0.5.2)
# Requirement already satisfied: sphinx-rtd-theme in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library->-r /content/requirements.txt (line 10)) (3.0.2)
# Requirement already satisfied: morfessor in /usr/local/lib/python3.10/dist-packages (from indic-nlp-library->-r /content/requirements.txt (line 10)) (2.0.6)
# Requirement already satisfied: natsort~=8.2.0 in /usr/local/lib/python3.10/dist-packages (from m4b-util->-r /content/requirements.txt (line 13)) (8.2.0)
# Requirement already satisfied: rich~=12.6.0 in /usr/local/lib/python3.10/dist-packages (from m4b-util->-r /content/requirements.txt (line 13)) (12.6.0)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray->-r /content/requirements.txt (line 18)) (8.1.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray->-r /content/requirements.txt (line 18)) (3.16.1)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray->-r /content/requirements.txt (line 18)) (4.23.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray->-r /content/requirements.txt (line 18)) (1.1.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray->-r /content/requirements.txt (line 18)) (4.25.5)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.10/dist-packages (from ray->-r /content/requirements.txt (line 18)) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.10/dist-packages (from ray->-r /content/requirements.txt (line 18)) (1.5.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->-r /content/requirements.txt (line 19)) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers->-r /content/requirements.txt (line 19)) (0.5.0)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers->-r /content/requirements.txt (line 19)) (0.20.3)
# Requirement already satisfied: libretranslatepy==2.1.1 in /usr/local/lib/python3.10/dist-packages (from translate->-r /content/requirements.txt (line 20)) (2.1.1)
# Requirement already satisfied: wasabi<1.0.0,>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from unidic->-r /content/requirements.txt (line 22)) (0.10.1)
# Requirement already satisfied: plac<2.0.0,>=1.1.3 in /usr/local/lib/python3.10/dist-packages (from unidic->-r /content/requirements.txt (line 22)) (1.4.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio>=4.44->-r /content/requirements.txt (line 8)) (3.10)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio>=4.44->-r /content/requirements.txt (line 8)) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->gradio>=4.44->-r /content/requirements.txt (line 8)) (1.2.2)
# Requirement already satisfied: psutil>=5 in /usr/local/lib/python3.10/dist-packages (from coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts->-r /content/requirements.txt (line 2)) (5.9.5)
# Requirement already satisfied: tensorboard>=2.17.0 in /usr/local/lib/python3.10/dist-packages (from coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts->-r /content/requirements.txt (line 2)) (2.17.1)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]>=2023.6.0->coqui-tts->-r /content/requirements.txt (line 2)) (3.11.11)
# Requirement already satisfied: Babel<3.0.0,>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts->-r /content/requirements.txt (line 2)) (2.16.0)
# Requirement already satisfied: dateparser~=1.1.1 in /usr/local/lib/python3.10/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts->-r /content/requirements.txt (line 2)) (1.1.8)
# Requirement already satisfied: gruut-ipa<1.0,>=0.12.0 in /usr/local/lib/python3.10/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts->-r /content/requirements.txt (line 2)) (0.13.0)
# Requirement already satisfied: gruut-lang-en~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts->-r /content/requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: jsonlines~=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts->-r /content/requirements.txt (line 2)) (1.2.0)
# Requirement already satisfied: networkx>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts->-r /content/requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: python-crfsuite~=0.9.7 in /usr/local/lib/python3.10/dist-packages (from gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts->-r /content/requirements.txt (line 2)) (0.9.11)
# Requirement already satisfied: gruut-lang-es~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gruut[de,es,fr]>=2.4.0->coqui-tts->-r /content/requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: gruut-lang-fr~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gruut[de,es,fr]>=2.4.0->coqui-tts->-r /content/requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: gruut-lang-de~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from gruut[de,es,fr]>=2.4.0->coqui-tts->-r /content/requirements.txt (line 2)) (2.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio>=4.44->-r /content/requirements.txt (line 8)) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.24.1->gradio>=4.44->-r /content/requirements.txt (line 8)) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio>=4.44->-r /content/requirements.txt (line 8)) (0.14.0)
# Requirement already satisfied: more_itertools>=8.5.0 in /usr/local/lib/python3.10/dist-packages (from inflect>=5.6.0->coqui-tts->-r /content/requirements.txt (line 2)) (10.5.0)
# Requirement already satisfied: typeguard>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from inflect>=5.6.0->coqui-tts->-r /content/requirements.txt (line 2)) (4.4.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts->-r /content/requirements.txt (line 2)) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts->-r /content/requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts->-r /content/requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts->-r /content/requirements.txt (line 2)) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts->-r /content/requirements.txt (line 2)) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts->-r /content/requirements.txt (line 2)) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts->-r /content/requirements.txt (line 2)) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa>=0.10.1->coqui-tts->-r /content/requirements.txt (line 2)) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->coqui-tts->-r /content/requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->coqui-tts->-r /content/requirements.txt (line 2)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->coqui-tts->-r /content/requirements.txt (line 2)) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->coqui-tts->-r /content/requirements.txt (line 2)) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->coqui-tts->-r /content/requirements.txt (line 2)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.7.0->coqui-tts->-r /content/requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from num2words>=0.5.11->coqui-tts->-r /content/requirements.txt (line 2)) (0.6.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio>=4.44->-r /content/requirements.txt (line 8)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0,>=1.0->gradio>=4.44->-r /content/requirements.txt (line 8)) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio>=4.44->-r /content/requirements.txt (line 8)) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.10/dist-packages (from pydantic>=2.0->gradio>=4.44->-r /content/requirements.txt (line 8)) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.23.0->deep_translator->-r /content/requirements.txt (line 4)) (3.4.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from rich~=12.6.0->m4b-util->-r /content/requirements.txt (line 13)) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from rich~=12.6.0->m4b-util->-r /content/requirements.txt (line 13)) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from smart-open>=1.8.1->gensim->-r /content/requirements.txt (line 7)) (1.17.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile>=0.12.0->coqui-tts->-r /content/requirements.txt (line 2)) (1.17.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (8.2.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (75.1.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: sudachipy!=0.6.1,>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (0.6.9)
# Requirement already satisfied: sudachidict-core>=20211220 in /usr/local/lib/python3.10/dist-packages (from spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (20241021)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=2.1->coqui-tts->-r /content/requirements.txt (line 2)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=2.1->coqui-tts->-r /content/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer<1.0,>=0.12->gradio>=4.44->-r /content/requirements.txt (line 8)) (1.5.4)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray->-r /content/requirements.txt (line 18)) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray->-r /content/requirements.txt (line 18)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray->-r /content/requirements.txt (line 18)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray->-r /content/requirements.txt (line 18)) (0.22.3)
# Requirement already satisfied: sphinx>=5.1.0 in /usr/local/lib/python3.10/dist-packages (from sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 10)) (8.1.3)
# Requirement already satisfied: docutils>=0.19 in /usr/local/lib/python3.10/dist-packages (from sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 10)) (0.21.2)
# Requirement already satisfied: sphinxcontrib-jquery<5,>=4 in /usr/local/lib/python3.10/dist-packages (from sphinx-rtd-theme->indic-nlp-library->-r /content/requirements.txt (line 10)) (4.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts->-r /content/requirements.txt (line 2)) (2.4.4)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts->-r /content/requirements.txt (line 2)) (4.0.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts->-r /content/requirements.txt (line 2)) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts->-r /content/requirements.txt (line 2)) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2023.6.0->coqui-tts->-r /content/requirements.txt (line 2)) (1.18.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile>=0.12.0->coqui-tts->-r /content/requirements.txt (line 2)) (2.22)
# Requirement already satisfied: tzlocal in /usr/local/lib/python3.10/dist-packages (from dateparser~=1.1.1->gruut>=2.4.0->gruut[de,es,fr]>=2.4.0->coqui-tts->-r /content/requirements.txt (line 2)) (5.2)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.10/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa>=0.10.1->coqui-tts->-r /content/requirements.txt (line 2)) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa>=0.10.1->coqui-tts->-r /content/requirements.txt (line 2)) (4.3.6)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa>=0.10.1->coqui-tts->-r /content/requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 10)) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 10)) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 10)) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 10)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 10)) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 10)) (2.0.0)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 10)) (2.2.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 10)) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 10)) (1.4.1)
# Requirement already satisfied: tomli>=2 in /usr/local/lib/python3.10/dist-packages (from sphinx>=5.1.0->sphinx-argparse->indic-nlp-library->-r /content/requirements.txt (line 10)) (2.2.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts->-r /content/requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts->-r /content/requirements.txt (line 2)) (1.69.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts->-r /content/requirements.txt (line 2)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts->-r /content/requirements.txt (line 2)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.17.0->coqui-tts-trainer<0.3.0,>=0.2.0->coqui-tts->-r /content/requirements.txt (line 2)) (3.1.3)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (0.1.5)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from weasel<0.5.0,>=0.1.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (0.20.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8,>=3->spacy[ja]<3.8,>=3->coqui-tts->-r /content/requirements.txt (line 2)) (1.2.1)

# %%
# @title 🚀 Run ebook2audiobook! (Make sure to set the runtime to have gpu to have faster generation speeds! :)

# Start the app with Share=True for the gradio interface
# !python /content/app.py --share
# Out:
# 2025-01-08 18:56:24.565267: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-01-08 18:56:24.586831: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-01-08 18:56:24.594508: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-01-08 18:56:24.611218: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-01-08 18:56:26.275485: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# * Running on local URL:  http://0.0.0.0:7860
# * Running on public URL: https://04f5580bf249d117ef.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Available Processor Unit: cuda
# /usr/local/lib/python3.10/dist-packages/ebooklib/epub.py:1395: UserWarning: In the future version we will turn default option ignore_ncx to True.
#   warnings.warn('In the future version we will turn default option ignore_ncx to True.')
# 1% Converting input to HTML...
# InputFormatPlugin: PDF Input running
# on /content/tmp/ebook-c0e62693-a8c5-4324-9c67-73b913fe4302/Profile.pdf
# pdftohtml log:
# Page-1
# Page-2
# Page-3
# Parsing all content...
# Generating default TOC from spine...
# 34% Running transforms on e-book...
# Merging user specified metadata...
# Detecting structure...
# Auto generated TOC with 0 entries.
# Flattening CSS and remapping font sizes...
# Source base font size is 12.00000pt
# Removing fake margins...
# Cleaning up manifest...
# Trimming unused files from manifest...
# Trimming 'index.xml' from manifest
# Creating EPUB Output...
# 67% Running EPUB Output plugin
# Splitting markup on page breaks and flow limits, if any...
# 	Looking for large trees in index.html...
# 	No large trees found
# Generating default cover
# This EPUB file has no Table of Contents. Creating a default TOC
# EPUB output written to /content/tmp/ebook-c0e62693-a8c5-4324-9c67-73b913fe4302/__Profile.epub
# Output saved to   /content/tmp/ebook-c0e62693-a8c5-4324-9c67-73b913fe4302/__Profile.epub
# /usr/local/lib/python3.10/dist-packages/ebooklib/epub.py:1423: FutureWarning: This search incorrectly ignores the root element, and will be fixed in a future version.  If you rely on the current behaviour, change it to './/xmlns:rootfile[@media-type]'
#   for root_file in tree.findall('//xmlns:rootfile[@media-type]', namespaces={'xmlns': NAMESPACES['CONTAINERNS']}):
# Loading TTS xtts model from MorganFreeman...
# model.pth: 100% 1.86G/1.86G [00:43<00:00, 42.6MB/s]
# xtts-v2/eng/MorganFreeman/config.json: 100% 4.36k/4.36k [00:00<00:00, 19.6MB/s]
# xtts-v2/eng/MorganFreeman/vocab.json: 100% 335k/335k [00:00<00:00, 2.04MB/s]
# Computing speaker latents...
# Processing file: /content/voices/eng/adult/male/MorganFreeman_24khz.wav
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, wav, from '/content/voices/eng/adult/male/MorganFreeman_24khz.wav':
#   Metadata:
#     encoder         : Lavf61.7.100
#   Duration: 00:00:11.52, bitrate: 3072 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 192000 Hz, mono, s16, 3072 kb/s
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> pcm_s16le (native))
# Press [q] to stop, [?] for help
# Output #0, wav, to '/content/tmp/ebook-c0e62693-a8c5-4324-9c67-73b913fe4302/Profile_voice.wav':
#   Metadata:
#     ISFT            : Lavf58.76.100
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 192000 Hz, mono, s16, 3072 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 pcm_s16le
# size=    4308kB time=00:00:08.58 bitrate=4109.5kbits/s speed=6.42x
# video:0kB audio:4308kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.002312%
# Processed file saved to: /content/tmp/ebook-c0e62693-a8c5-4324-9c67-73b913fe4302/Profile_voice.wav
# convert_chapters_to_audio 0.00%:   0% 0/32 [00:00<?, ?step/s]
# Chapter 1 containing 32 sentences...
# Processing 0.00%:   3% 1/32 [00:03<01:42,  3.30s/step]               Sentence: LinkedIn, Resume;
#
# Processing 3.12%:   6% 2/32 [00:08<02:07,  4.26s/step]Sentence: Contact Anubhav Kumar
# anubhavkumar;
# 995@gmail;
# com
# Hardware Engineer @ Qualcomm | VLSI | IIT Roorkee | BEL
# www;
# linkedin;
# com/in/anubhavk 95 Bengaluru, Karnataka,
# Processing 6.25%:   9% 3/32 [00:16<02:55,  6.05s/step]Sentence: India
# (LinkedIn)
# Top Skills Summary
# SOCs Highly accomplished and results-driven Hardware Physical Design
# STA Engineer with a strong focus on Static Timing Analysis (STA),
# Processing 9.38%:  12% 4/32 [00:21<02:35,  5.55s/step]Sentence: Signal
# Power Integrity Integrity (SI) signoff, and Power Delivery Network (PDN) analysis for
# cutting-edge semiconductor designs;
#
# At Qualcomm,
# Processing 12.50%:  16% 5/32 [00:25<02:21,  5.24s/step]Sentence: I've contributed to the successful tapeouts of
# advanced SoCs down to 3 nm technology, achieving significant
# improvements in performance, power,
# Processing 15.62%:  19% 6/32 [00:31<02:20,  5.39s/step]Sentence: and area (PPA);
#  My expertise
# lies in closing timing and power integrity on complex blocks,
# collaborating effectively with cross-functional teams,
# Processing 18.75%:  22% 7/32 [00:35<02:06,  5.04s/step]Sentence: and leveraging
# automation to enhance efficiency;
#
# Recent highlights include achieving ~10% higher frequencies on
# critical GPU blocks through strategic clock tweaks,
# Processing 21.88%:  25% 8/32 [00:38<01:45,  4.41s/step]Sentence: realizing a 60 mV
# uplift margin in dynamic IR drop analysis,
# Processing 25.00%:  28% 9/32 [00:42<01:36,  4.19s/step]Sentence: and reducing signoff
# closure turnaround time by 28% with key automations;
#
# I'm passionate about innovation and currently working on the
# application of Large Language Models (LLMs)
# Processing 28.12%:  31% 10/32 [00:45<01:24,  3.86s/step]Sentence: to revolutionize design
# and signoff methodologies,
# Processing 31.25%:  34% 11/32 [00:49<01:20,  3.82s/step]Sentence: including building a natural language
# interface for accessing internal knowledge and automating key
# analysis tasks using AI agents;
# Processing 34.38%:  38% 12/32 [00:54<01:23,  4.20s/step]Sentence: Seeking to connect with professionals in the semiconductor industry,
# particularly those working on advanced node technologies, AI-
# driven design methodologies,
# Processing 37.50%:  41% 13/32 [00:55<01:03,  3.32s/step]Sentence: and power integrity solutions;
#  Open to
# discussing opportunities and collaborations in the field of Physical
# Design and Signoff;
# Processing 40.62%:  44% 14/32 [00:57<00:50,  2.81s/step]Sentence: #PhysicalDesign #STA #SignalIntegrity #PDN #PowerIntegrity
# #Semiconductor #VLSI #3 nm #Automation #AI #MachineLearning
# #Qualcomm
# Experience
# Qualcomm
# 4 years 6 months
# Senior Engineer
# November
# Processing 43.75%:  47% 15/32 [00:59<00:42,  2.47s/step]Sentence: 2022 - Present (2 years 2 months)
# Bangalore Urban, Karnataka, India
# 1;
#  Led STA closure for critical high Performance Cores GPU/SOC and
# interfaces,
# Processing 46.88%:  50% 16/32 [01:06<01:01,  3.81s/step]Sentence: achieving ~10% frequency increase via clock tweaks and 22%
# leakage/area recovery through selective "don't touch" strategy and logic island
# optimization,
# Processing 50.00%:  53% 17/32 [01:10<00:58,  3.91s/step]Sentence: improving skew and congestion;
#
# 2;
#  Drove Power Delivery Signoff (IR/EM/ESD) for sub-10 nm SoCs,
# Processing 53.12%:  56% 18/32 [01:15<01:00,  4.35s/step]Sentence: achieving
# 60 mV VCD dynamic IR drop margin uplift and 28% PDN closure TAT reduction
# via automation and strategic placement;
#
# 3;
#  Implemented Timing, Power, and Area/Leakage ECOs,
# Processing 56.25%:  59% 19/32 [01:20<00:59,  4.61s/step]Sentence: resolving TDRC
# violations while optimizing PG grid resistance, IR drop, EM, and inrush;
#
# 4;
#  Developed and deployed automation scripts (GDHS chaining, Inrush,
# PDN, STA, CLP),
# Processing 59.38%:  62% 20/32 [01:26<00:59,  4.99s/step]Sentence: significantly reducing manual reviews and improving project
# runtime;
#
# 5;
#  Enabled selective Timing what-if analysis for PDN drops,
# Processing 62.50%:  66% 21/32 [01:28<00:45,  4.15s/step]Sentence: accelerating ECO
# turnaround by 60%;
#
# 6;
#  Developing an LLM-based chat interface for team knowledge access and AI
# agents for automated analysis in PD and signoff domains;
#
# 7;
# Processing 65.62%:  69% 22/32 [01:31<00:36,  3.70s/step]Sentence: Collaborated with Design, Synthesis, Verification, Constraints,
# Processing 68.75%:  72% 23/32 [01:39<00:43,  4.86s/step]Sentence: and RDL
# teams for high-quality signoff;
#
# 8;
#  Integrated IP blocks and managed static/analog routing for STA/PDN
# signoff;
#
# 9;
#  Proficient with Synopsys (DC, PrimeTime, PT-SI, Tweaker),
# Processing 71.88%:  75% 24/32 [01:43<00:37,  4.64s/step]Sentence: Cadence
# (Tempus, Tempus-SI, RTL Compiler, Virtuoso, LEC, CLP, Voltus), and Ansys
# (Redhawk, Redhawk-SC, Pathfinder-SC) EDA tools;
#
# 10;
#  Skilled in scripting (Tcl, Shell, Python,
# Processing 75.00%:  78% 25/32 [01:46<00:30,  4.36s/step]Sentence: Perl);
#
# PD sign-off Engineer
# July 2020 - November 2022 (2 years 5 months)
# Bangalore Urban, Karnataka,
# Processing 78.12%:  81% 26/32 [02:02<00:47,  7.84s/step]Sentence: India
# Working on PD STA/Signal Integrity/PDN SOC sign-off
# Qualcomm
# Hardware Engineering Intern
# May 2019 - July 2019 (3 months)
# Noida, Uttar Pradesh,
# Processing 81.25%:  84% 27/32 [02:10<00:38,  7.78s/step]Sentence: India
# Worked in design technology and timing sign-off team implementing different
# timing checks e;
# g;
#  DCD (duty cycle degradation),
# Processing 84.38%:  88% 28/32 [02:17<00:29,  7.46s/step]Sentence: R 2 R (rail to rail check) and
# Fmax Calculator for given Design;
#
# Bharat Electronics
# Dy Engineer
# March 2018 - July 2018 (5 months)
# Processing 87.50%:  91% 29/32 [02:22<00:20,  6.86s/step]Sentence: Banglore
# Worked on Several Areas of EVM and VVPAT design and development;
#
# Lava International Limited
# QA/QC
# June 2016 - September 2017 (1 year 4 months)
# Noida Area,
# Processing 90.62%:  94% 30/32 [02:25<00:11,  5.71s/step]Sentence: India
# Hardware QA and Reliability Assurance;
#
# Education
# Indian Institute of Technology, Roorkee
# Master of Technology - MTech,
# Processing 93.75%:  97% 31/32 [02:31<00:05,  5.73s/step]Sentence: Microelectronics and VLSI
# Design · (2018 - 2020)
# Lovely Professional University
# Bachelor of Technology (B;
# Tech;
# ), Electrical,
# Processing 96.88%: 100% 32/32 [02:34<00:00,  4.81s/step]Sentence: Electronics and Communications
# Engineering · (2012 - 2016)
# Processing 96.88%: 100% 32/32 [02:34<00:00,  4.81s/step]
# End of Chapter 1
# Combined audio saved to /content/tmp/ebook-c0e62693-a8c5-4324-9c67-73b913fe4302/chapters_f7e84f02feeeff602823c61ef7c6bc99/chapter_1.wav
# Combining chapter 1 to audio, sentence 0 to 31
# Processing 96.88%: 100% 32/32 [02:34<00:00,  4.82s/step]
# Combined audio saved to /content/tmp/ebook-c0e62693-a8c5-4324-9c67-73b913fe4302/Resume.wav
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Guessed Channel Layout for Input Stream #0.0 : mono
# Input #0, wav, from '/content/tmp/ebook-c0e62693-a8c5-4324-9c67-73b913fe4302/Resume.wav':
#   Duration: 00:04:41.54, bitrate: 384 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 24000 Hz, mono, s16, 384 kb/s
# Input #1, ffmetadata, from '/content/tmp/ebook-c0e62693-a8c5-4324-9c67-73b913fe4302/metadata.txt':
#   Metadata:
#     title           : Resume
#     artist          : LinkedIn
#     year            : 2025
#   Duration: 00:04:41.54, start: 0.000000, bitrate: 0 kb/s
#   Chapters:
#     Chapter #1:0: start 0.000000, end 281.536000
#       Metadata:
#         title           : Chapter 1
# Input #2, image2, from '/content/tmp/ebook-c0e62693-a8c5-4324-9c67-73b913fe4302/Profile.jpg':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 27903 kb/s
#   Stream #2:0: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1200x1600 [SAR 96:96 DAR 3:4], 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (pcm_s16le (native) -> aac (native))
#   Stream #2:0 -> #0:1 (copy)
# Press [q] to stop, [?] for help
# Output #0, ipod, to '/content/audiobooks/gui/gradio/web-c0e62693-a8c5-4324-9c67-73b913fe4302/Resume.m4b':
#   Metadata:
#     title           : Resume
#     artist          : LinkedIn
#     year            : 2025
#     encoder         : Lavf58.76.100
#   Chapters:
#     Chapter #0:0: start 0.000000, end 281.536000
#       Metadata:
#         title           : Chapter 1
#   Stream #0:0: Audio: aac (LC) (mp4a / 0x6134706D), 44100 Hz, mono, fltp, 128 kb/s
#     Metadata:
#       encoder         : Lavc58.134.100 aac
#   Stream #0:1: Video: mjpeg (Baseline), yuvj420p(pc, bt470bg/unknown/unknown), 1200x1600 [SAR 96:96 DAR 3:4], q=2-31, 25 fps, 25 tbr, 12800 tbn, 25 tbc (attached pic)
# [ipod @ 0x55ab3bc76940] Starting second pass: moving the moov atom to the beginning of the file
# frame=    1 fps=0.2 q=-1.0 Lsize=    4615kB time=00:04:41.51 bitrate= 134.3kbits/s speed=54.1x
# video:136kB audio:4430kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.070663%
# [aac @ 0x55ab3bc77a80] Qavg: 12035.709
# Keyboard interruption in main thread... closing server.
# Server interrupted by user. Shutting down...
# Killing tunnel 0.0.0.0:7860 <> https://04f5580bf249d117ef.gradio.live
